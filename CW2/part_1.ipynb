# %%
from utilities import *
from perceptron import *

# %% [markdown]
# # Part I

# %% [markdown]
# ### Experience 1

# %%
experiment_1()
# Out:
# 100%|██████████| 7/7 [17:58<00:00, 154.03s/it]
#                             1                 2                 3  \
# train error   0.086 +- 0.0137  0.0133 +- 0.0085   0.0116 +- 0.023
# test error   0.1106 +- 0.0147   0.044 +- 0.0086  0.0341 +- 0.0046
#
#                             4                 5                6  \
# train error  0.0029 +- 0.0028  0.0035 +- 0.0034  0.0028 +- 0.003
# test error    0.0275 +- 0.004  0.0302 +- 0.0057   0.03 +- 0.0038
#
#                             7
# train error   0.0025 +- 0.003
# test error   0.0289 +- 0.0033

# %% [markdown]
# ### Experiment 2

# %%
res_2 = experiment_2()
# Out:
# 100%|██████████| 20/20 [15:24<00:00, 46.24s/it]
# mean +_ std of test error is 0.0438 +_ 0.0043
# mean +_ std of d_star is 6.0500 +_ 1.0235

# %% [markdown]
# ### Experiment 3

# %%
df1, df2, sorted_counter_X_error = experiment_3_and_4()
# Out:
# 100%|██████████| 20/20 [15:47<00:00, 47.40s/it]

# %%
df1.to_csv('df1.csv')
print(df1)
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.000000  0.002249  0.003373  0.003533  0.001283  0.007716  0.003173
# 1  0.000000  0.000000  0.000380  0.000194  0.001210  0.001170  0.001990
# 2  0.003937  0.006322  0.000000  0.007337  0.005201  0.006111  0.002093
# 3  0.003279  0.005124  0.009502  0.000000  0.000852  0.039570  0.000000
# 4  0.006102  0.027565  0.010047  0.000883  0.000000  0.009786  0.006700
# 5  0.007424  0.002866  0.003855  0.010361  0.003823  0.000000  0.006331
# 6  0.006814  0.010238  0.004455  0.000000  0.009409  0.007819  0.000000
# 7  0.000273  0.007352  0.007305  0.001475  0.011760  0.001498  0.000000
# 8  0.005898  0.010599  0.007987  0.014492  0.005746  0.024424  0.002800
# 9  0.000957  0.005926  0.002727  0.001529  0.014135  0.010178  0.000601
#
#           7         8         9
# 0  0.000653  0.002703  0.000331
# 1  0.000562  0.001376  0.000000
# 2  0.007042  0.003929  0.000508
# 3  0.007825  0.015027  0.000654
# ...

# %%
df2.to_csv('df2.csv')
print(df2)
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.000000  0.002701  0.003288  0.003358  0.001886  0.006361  0.003285
# 1  0.000000  0.000000  0.001141  0.000845  0.002202  0.002153  0.002711
# 2  0.004053  0.008181  0.000000  0.005283  0.004558  0.004525  0.003457
# 3  0.004395  0.005551  0.005927  0.000000  0.002674  0.016105  0.000000
# 4  0.008396  0.022878  0.010712  0.002104  0.000000  0.013305  0.006534
# 5  0.006787  0.004766  0.006236  0.009423  0.005746  0.000000  0.007351
# 6  0.005276  0.007992  0.005210  0.000000  0.005304  0.008264  0.000000
# 7  0.001191  0.008328  0.008687  0.003171  0.007603  0.002601  0.000000
# 8  0.007585  0.008048  0.008258  0.009479  0.006697  0.010876  0.004019
# 9  0.002281  0.008291  0.004019  0.003276  0.009256  0.011679  0.001802
#
#           7         8         9
# 0  0.001308  0.002616  0.000994
# 1  0.001339  0.001879  0.000000
# 2  0.006305  0.004388  0.001523
# 3  0.007889  0.010776  0.001986
# ...

# %% [markdown]
# ### Experiment 4

# %%
plot_bad_digits(sorted_counter_X_error)

# %% [markdown]
# ### Experiment 5

# %%
experiment_5_1()
# c = [1e-2, 1e-1, 1e0, 1e1, 1e2]
# the printed c is the index of elements in the above list
# Out:
# 100%|██████████| 5/5 [39:52<00:00, 478.45s/it]
# mean +_ std of train error with  c=1 is 0.0041 +_ 0.0040
# mean +_ std of train error with  c=2 is 0.0105 +_ 0.0225
# mean +_ std of train error with  c=3 is 0.0297 +_ 0.0329
# mean +_ std of train error with  c=4 is 0.2241 +_ 0.0267
# mean +_ std of train error with  c=5 is 0.7231 +_ 0.0030
# mean +_ std of test error with  c=1 is 0.0297 +_ 0.0048
# mean +_ std of test error with  c=2 is 0.0528 +_ 0.0054
# mean +_ std of test error with  c=3 is 0.0695 +_ 0.0041
# mean +_ std of test error with  c=4 is 0.1656 +_ 0.0136
# mean +_ std of test error with  c=5 is 0.7195 +_ 0.0100

# %%
experiment_5_2()
# Out:
#  10%|█         | 2/20 [05:10<46:28, 154.94s/it]
